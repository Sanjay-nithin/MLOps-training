# %%
! uv pip install ultralytics
# Out:
# Using Python 3.12.13 environment at: /usr
# Resolved 54 packages in 808ms
# Prepared 2 packages in 93ms
# Installed 2 packages in 13ms
#  + ultralytics==8.4.56
#  + ultralytics-thop==2.0.19

# %%
import ultralytics
from ultralytics import YOLO

ultralytics.checks()
# Out:
# Ultralytics 8.4.56 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 47.2/112.6 GB disk)

# %%
! yolo detect train model='yolo26l.pt' data=/content/drive/MyDrive/Datasets/datasets/bees/dataset.yaml epochs=100 imgsz=1024 batch=8
# Out:
# ...
# Ultralytics 8.4.56 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
! yolo detect predict \
model=/content/runs/detect/train/weights/best.pt \
source=/content/drive/MyDrive/Datasets/convertedImages \
save_txt=True \
save_conf=True
# Out:
# Ultralytics 8.4.56 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26l summary (fused): 190 layers, 24,746,511 parameters, 0 gradients, 86.1 GFLOPs
#
# image 1/2165 /content/drive/MyDrive/Datasets/convertedImages/118_0000.jpg: 576x1024 1 bee, 60.6ms
# image 2/2165 /content/drive/MyDrive/Datasets/convertedImages/118_0001.jpg: 576x1024 (no detections), 46.6ms
# image 3/2165 /content/drive/MyDrive/Datasets/convertedImages/118_0002.jpg: 576x1024 1 bee, 41.4ms
# image 4/2165 /content/drive/MyDrive/Datasets/convertedImages/118_0003.jpg: 576x1024 1 bee, 40.9ms
# image 5/2165 /content/drive/MyDrive/Datasets/convertedImages/118_0004.jpg: 576x1024 1 bee, 40.2ms
# image 6/2165 /content/drive/MyDrive/Datasets/convertedImages/118_0005.jpg: 576x1024 1 bee, 37.1ms
# image 7/2165 /content/drive/MyDrive/Datasets/convertedImages/118_0006.jpg: 576x1024 1 bee, 34.2ms
# image 8/2165 /content/drive/MyDrive/Datasets/convertedImages/118_0007.jpg: 576x1024 1 bee, 34.1ms
# ...

# %%
# !zip -r predicted_labels.zip /content/runs/detect/predict-2
# Out:
#   adding: content/runs/detect/predict-2/ (stored 0%)
#   adding: content/runs/detect/predict-2/118_2331.jpg (deflated 0%)
#   adding: content/runs/detect/predict-2/118_0935.jpg (deflated 0%)
#   adding: content/runs/detect/predict-2/118_1761.jpg (deflated 0%)
#   adding: content/runs/detect/predict-2/118_2163.jpg (deflated 0%)
#   adding: content/runs/detect/predict-2/118_2257.jpg (deflated 0%)
#   adding: content/runs/detect/predict-2/118_2198.jpg (deflated 0%)
#   adding: content/runs/detect/predict-2/118_0236.jpg (deflated 0%)
#   adding: content/runs/detect/predict-2/118_2354.jpg (deflated 0%)
#   adding: content/runs/detect/predict-2/118_2139.jpg (deflated 0%)
#   adding: content/runs/detect/predict-2/118_1137.jpg (deflated 0%)
#   adding: content/runs/detect/predict-2/118_0269.jpg (deflated 0%)
#   adding: content/runs/detect/predict-2/118_0939.jpg (deflated 0%)
#   adding: content/runs/detect/predict-2/118_0130.jpg (deflated 0%)
# ...
